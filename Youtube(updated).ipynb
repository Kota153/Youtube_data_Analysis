# %%
# Importing all required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import ipywidgets as widgets
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# Read My CSV and JSON Files
data = pd.read_csv('/content/drive/MyDrive/Youtube_2/US_youtube_trending_data.csv')
cat = pd.read_json('/content/drive/MyDrive/Youtube_2/US_category_id.json')

# %%
data
# Out:
#            video_id                                              title  \
# 0       3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1       M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2       J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3       kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4       VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...             ...                                                ...
# 199185  drvPVTMQ8fU  Film Theory: Mario is IMMORTAL! (Super Mario M...
# 199186  0nMgqZtksyc  Aaron Rodgers Has OFFICIALLY Been Traded To Th...
# 199187  X0dLL4uYivE               My First Game In Japan Broke Records
# 199188  oWc6RY8U6KQ  MY DAUGHTER'S DREAM VACATION in Alphabetical O...
# 199189  E9kW_dUlTV0         THE CHAMPIONS! Pitch Invasion & Chest Cam!
#
#                  publishedAt                 channelId  \
# 0       2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg
# 1       2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A
# 2       2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g
# 3       2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg
# 4       2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A
# ...                      ...                       ...
# 199185  2023-04-23T17:05:07Z  UC3sznuotAs2ohg_U__Jzj_Q
# 199186  2023-04-24T20:40:51Z  UCxcTeAKWJca6XyJ37_ZoKIQ
# 199187  2023-04-23T15:15:01Z  UCczKsS4gTjJzU5zayrNnwEA
# 199188  2023-04-22T14:00:09Z  UCKaCalz5N5ienIbfPzEbYuA
# 199189  2023-04-23T18:55:12Z  UCi33DX7KG3M3bI0ipjOP2Eg
#
#                        channelTitle  categoryId         trending_date  \
# 0                          Brawadis          22  2020-08-12T00:00:00Z
# 1                      Apex Legends          20  2020-08-12T00:00:00Z
# 2                     jacksepticeye          24  2020-08-12T00:00:00Z
# 3                               XXL          10  2020-08-12T00:00:00Z
# 4                          Mr. Kate          26  2020-08-12T00:00:00Z
# ...                             ...         ...                   ...
# 199185           The Film Theorists           1  2023-04-30T00:00:00Z
# 199186          The Pat McAfee Show          17  2023-04-30T00:00:00Z
# 199187                 Trevor Bauer          17  2023-04-30T00:00:00Z
# 199188                Jordan Matter          24  2023-04-30T00:00:00Z
# 199189  Ben Foster - The Cycling GK          17  2023-04-30T00:00:00Z
#
#                                                      tags  view_count   likes  \
# 0       brawadis|prank|basketball|skits|ghost|funny vi...     1514614  156908
# 1       Apex Legends|Apex Legends characters|new Apex ...     2381688  146739
# 2       jacksepticeye|funny|funny meme|memes|jacksepti...     2038853  353787
# 3       xxl freshman|xxl freshmen|2020 xxl freshman|20...      496771   23251
# 4       The LaBrant Family|DIY|Interior Design|Makeove...     1123889   45802
# ...                                                   ...         ...     ...
# 199185  Mario|mario movie|super mario bros|super mario...     2475971  109521
# 199186  pat mcafee|podcast|sports|nfl|ncaa|football|fo...      519306   10084
# 199187                                             [None]     1100305   28114
# 199188  jordan matter|salish matter|hudson matter|nali...     7368531  105583
# 199189  The Cycling GK|English premier league|soccer|B...     1870384   83156
#
#         dislikes  comment_count  \
# 0           5855          35313
# 1           2794          16549
# 2           2628          40221
# 3           1856           7647
# 4            964           2196
# ...          ...            ...
# 199185         0           6203
# 199186         0           1306
# 199187         0           1328
# 199188         0          72654
# 199189         0           6558
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# 1       https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg              False
# 2       https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg              False
# 3       https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg              False
# 4       https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg              False
# ...                                                ...                ...
# 199185  https://i.ytimg.com/vi/drvPVTMQ8fU/default.jpg              False
# 199186  https://i.ytimg.com/vi/0nMgqZtksyc/default.jpg              False
# 199187  https://i.ytimg.com/vi/X0dLL4uYivE/default.jpg              False
# 199188  https://i.ytimg.com/vi/oWc6RY8U6KQ/default.jpg              False
# 199189  https://i.ytimg.com/vi/E9kW_dUlTV0/default.jpg              False
#
#         ratings_disabled
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 199185             False
# 199186             False
# 199187             False
# 199188             False
# 199189             False
#
# [199190 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# video_id                0
# title                   0
# publishedAt             0
# channelId               0
# channelTitle            0
# categoryId              0
# trending_date           0
# tags                    0
# view_count              0
# likes                   0
# dislikes                0
# comment_count           0
# thumbnail_link          0
# comments_disabled       0
# ratings_disabled        0
# description          4141
# dtype: int64

# %%
data.drop(['description'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-bfc2f3733e16> in <cell line: 1>()
# ----> 1 data.drop(['description','tags','thumbnail_link'], axis=1, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['description'] not found in axis"

# %%
data.drop(['tags','thumbnail_link'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199190 entries, 0 to 199189
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           199190 non-null  object
#  1   title              199190 non-null  object
#  2   publishedAt        199190 non-null  object
#  3   channelId          199190 non-null  object
#  4   channelTitle       199190 non-null  object
#  5   categoryId         199190 non-null  int64
#  6   trending_date      199190 non-null  object
#  7   view_count         199190 non-null  int64
#  8   likes              199190 non-null  int64
#  9   dislikes           199190 non-null  int64
#  10  comment_count      199190 non-null  int64
#  11  comments_disabled  199190 non-null  bool
#  12  ratings_disabled   199190 non-null  bool
# dtypes: bool(2), int64(5), object(6)
# memory usage: 17.1+ MB

# %%
# converting dtype in to datatime formate of publishedAt and trending_date columns
data['publishedAt'] = pd.to_datetime(data['publishedAt'])
data['trending_date'] = pd.to_datetime(data['trending_date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199190 entries, 0 to 199189
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           199190 non-null  object
#  1   title              199190 non-null  object
#  2   publishedAt        199190 non-null  datetime64[ns, UTC]
#  3   channelId          199190 non-null  object
#  4   channelTitle       199190 non-null  object
#  5   categoryId         199190 non-null  int64
#  6   trending_date      199190 non-null  datetime64[ns, UTC]
#  7   view_count         199190 non-null  int64
#  8   likes              199190 non-null  int64
#  9   dislikes           199190 non-null  int64
#  10  comment_count      199190 non-null  int64
#  11  comments_disabled  199190 non-null  bool
#  12  ratings_disabled   199190 non-null  bool
# dtypes: bool(2), datetime64[ns, UTC](2), int64(5), object(4)
# memory usage: 17.1+ MB

# %%
# extrating the year and month from publishedAt and trending_date columns
data['p_year'] = data['publishedAt'].dt.year
data['p_month'] = data['publishedAt'].dt.month_name()
data['t_year'] = data['trending_date'].dt.year
data['t_month'] = data['trending_date'].dt.month_name()

# %%
data
# Out:
#            video_id                                              title  \
# 0       3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1       M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2       J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3       kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4       VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...             ...                                                ...
# 199185  drvPVTMQ8fU  Film Theory: Mario is IMMORTAL! (Super Mario M...
# 199186  0nMgqZtksyc  Aaron Rodgers Has OFFICIALLY Been Traded To Th...
# 199187  X0dLL4uYivE               My First Game In Japan Broke Records
# 199188  oWc6RY8U6KQ  MY DAUGHTER'S DREAM VACATION in Alphabetical O...
# 199189  E9kW_dUlTV0         THE CHAMPIONS! Pitch Invasion & Chest Cam!
#
#                      publishedAt                 channelId  \
# 0      2020-08-11 19:20:14+00:00  UCvtRTOMP2TqYqu51xNrqAzg
# 1      2020-08-11 17:00:10+00:00  UC0ZV6M2THA81QT9hrVWJG3A
# 2      2020-08-11 16:34:06+00:00  UCYzPXprvl5Y-Sf0g4vX-m6g
# 3      2020-08-11 16:38:55+00:00  UCbg_UMjlHJg_19SZckaKajg
# 4      2020-08-11 15:10:05+00:00  UCDVPcEbVLQgLZX0Rt6jo34A
# ...                          ...                       ...
# 199185 2023-04-23 17:05:07+00:00  UC3sznuotAs2ohg_U__Jzj_Q
# 199186 2023-04-24 20:40:51+00:00  UCxcTeAKWJca6XyJ37_ZoKIQ
# 199187 2023-04-23 15:15:01+00:00  UCczKsS4gTjJzU5zayrNnwEA
# 199188 2023-04-22 14:00:09+00:00  UCKaCalz5N5ienIbfPzEbYuA
# 199189 2023-04-23 18:55:12+00:00  UCi33DX7KG3M3bI0ipjOP2Eg
#
#                        channelTitle  categoryId             trending_date  \
# 0                          Brawadis          22 2020-08-12 00:00:00+00:00
# 1                      Apex Legends          20 2020-08-12 00:00:00+00:00
# 2                     jacksepticeye          24 2020-08-12 00:00:00+00:00
# 3                               XXL          10 2020-08-12 00:00:00+00:00
# 4                          Mr. Kate          26 2020-08-12 00:00:00+00:00
# ...                             ...         ...                       ...
# 199185           The Film Theorists           1 2023-04-30 00:00:00+00:00
# 199186          The Pat McAfee Show          17 2023-04-30 00:00:00+00:00
# 199187                 Trevor Bauer          17 2023-04-30 00:00:00+00:00
# 199188                Jordan Matter          24 2023-04-30 00:00:00+00:00
# 199189  Ben Foster - The Cycling GK          17 2023-04-30 00:00:00+00:00
#
#         view_count   likes  dislikes  comment_count  comments_disabled  \
# 0          1514614  156908      5855          35313              False
# 1          2381688  146739      2794          16549              False
# 2          2038853  353787      2628          40221              False
# 3           496771   23251      1856           7647              False
# 4          1123889   45802       964           2196              False
# ...            ...     ...       ...            ...                ...
# 199185     2475971  109521         0           6203              False
# 199186      519306   10084         0           1306              False
# 199187     1100305   28114         0           1328              False
# 199188     7368531  105583         0          72654              False
# 199189     1870384   83156         0           6558              False
#
#         ratings_disabled  p_year p_month  t_year t_month
# 0                  False    2020  August    2020  August
# 1                  False    2020  August    2020  August
# 2                  False    2020  August    2020  August
# 3                  False    2020  August    2020  August
# 4                  False    2020  August    2020  August
# ...                  ...     ...     ...     ...     ...
# 199185             False    2023   April    2023   April
# 199186             False    2023   April    2023   April
# 199187             False    2023   April    2023   April
# 199188             False    2023   April    2023   April
# 199189             False    2023   April    2023   April
#
# [199190 rows x 17 columns]

# %%
cat
# Out:
#                                  kind                         etag  \
# 0   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 1   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 2   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 3   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 4   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 5   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 6   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 7   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 8   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 9   youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 10  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 11  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 12  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 13  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 14  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 15  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 16  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 17  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 18  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 19  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 20  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 21  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 22  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 23  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 24  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 25  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 26  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 27  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 28  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 29  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 30  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
# 31  youtube#videoCategoryListResponse  HIrK3n45Uw2IYz9_U2-gK1OsXvo
#
#                                                 items
# 0   {'kind': 'youtube#videoCategory', 'etag': 'IfW...
# 1   {'kind': 'youtube#videoCategory', 'etag': '5XG...
# 2   {'kind': 'youtube#videoCategory', 'etag': 'HCj...
# 3   {'kind': 'youtube#videoCategory', 'etag': 'ra8...
# 4   {'kind': 'youtube#videoCategory', 'etag': '7mq...
# 5   {'kind': 'youtube#videoCategory', 'etag': '0Z6...
# 6   {'kind': 'youtube#videoCategory', 'etag': 'K_-...
# 7   {'kind': 'youtube#videoCategory', 'etag': 'I3I...
# 8   {'kind': 'youtube#videoCategory', 'etag': 'D1W...
# 9   {'kind': 'youtube#videoCategory', 'etag': 'QME...
# 10  {'kind': 'youtube#videoCategory', 'etag': 'v2n...
# 11  {'kind': 'youtube#videoCategory', 'etag': 'Qi1...
# 12  {'kind': 'youtube#videoCategory', 'etag': 'IbG...
# 13  {'kind': 'youtube#videoCategory', 'etag': 'gYz...
# 14  {'kind': 'youtube#videoCategory', 'etag': 'hHU...
# 15  {'kind': 'youtube#videoCategory', 'etag': 'KEd...
# 16  {'kind': 'youtube#videoCategory', 'etag': 'Aio...
# 17  {'kind': 'youtube#videoCategory', 'etag': 'tMf...
# 18  {'kind': 'youtube#videoCategory', 'etag': 'tot...
# 19  {'kind': 'youtube#videoCategory', 'etag': 'LNg...
# 20  {'kind': 'youtube#videoCategory', 'etag': 'har...
# 21  {'kind': 'youtube#videoCategory', 'etag': 'M6Y...
# 22  {'kind': 'youtube#videoCategory', 'etag': 'ZFb...
# 23  {'kind': 'youtube#videoCategory', 'etag': 'FD7...
# 24  {'kind': 'youtube#videoCategory', 'etag': '7fv...
# 25  {'kind': 'youtube#videoCategory', 'etag': 'H6d...
# 26  {'kind': 'youtube#videoCategory', 'etag': 'Z3y...
# 27  {'kind': 'youtube#videoCategory', 'etag': '3F8...
# 28  {'kind': 'youtube#videoCategory', 'etag': 'Hwu...
# 29  {'kind': 'youtube#videoCategory', 'etag': 'qJ2...
# 30  {'kind': 'youtube#videoCategory', 'etag': '2sK...
# 31  {'kind': 'youtube#videoCategory', 'etag': '3Ia...

# %%
cat['items'].values[5]['snip']
# Out:
# {'kind': 'youtube#videoCategory',
#  'etag': '0Z6uGkj97NgjD-X3pkA-nL18Hqk',
#  'id': '18',
#  'snippet': {'title': 'Short Movies',
#   'assignable': False,
#   'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}}

# %%
t = [cat['items'].values[i]['snippet']['title'] for i in range(len(cat['items']))]

# %%
i = [cat['items'].values[i]['id'] for i in range(len(cat['items']))]

# %%
json = pd.DataFrame({'categoryId':i,'Genre':t})

# %%
json['categoryId'] = pd.to_numeric(json['categoryId'])

# %%
json
# Out:
#     categoryId                  Genre
# 0            1       Film & Animation
# 1            2       Autos & Vehicles
# 2           10                  Music
# 3           15         Pets & Animals
# 4           17                 Sports
# 5           18           Short Movies
# 6           19        Travel & Events
# 7           20                 Gaming
# 8           21          Videoblogging
# 9           22         People & Blogs
# 10          23                 Comedy
# 11          24          Entertainment
# 12          25        News & Politics
# 13          26          Howto & Style
# 14          27              Education
# 15          28   Science & Technology
# 16          29  Nonprofits & Activism
# 17          30                 Movies
# 18          31        Anime/Animation
# 19          32       Action/Adventure
# 20          33               Classics
# 21          34                 Comedy
# 22          35            Documentary
# 23          36                  Drama
# 24          37                 Family
# 25          38                Foreign
# 26          39                 Horror
# 27          40         Sci-Fi/Fantasy
# 28          41               Thriller
# 29          42                 Shorts
# 30          43                  Shows
# 31          44               Trailers

# %%
json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   categoryId  32 non-null     int64
#  1   Genre       32 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 640.0+ bytes

# %%
df = pd.merge(data,json,on='categoryId',how = 'inner')

# %%
df
# Out:
#            video_id                                              title  \
# 0       3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1       49Z6Mv4_WCA                 i don't know what im doing anymore
# 2       nt3VVyv5pxQ                     Try Not To Laugh Challenge #51
# 3       BNeDH6UTmXw               Ten Minutes with Tyler Cameron | Q&A
# 4       gPdUslndvVI                            Our Farm Got Destroyed.
# ...             ...                                                ...
# 199185  F-kvFACZ5yE  Denzel Washington Reveals the Aftermath of Wil...
# 199186  F-kvFACZ5yE  Denzel Washington Reveals the Aftermath of Wil...
# 199187  F-kvFACZ5yE  Denzel Washington Reveals the Aftermath of Wil...
# 199188  F-kvFACZ5yE  Denzel Washington Reveals the Aftermath of Wil...
# 199189  F-kvFACZ5yE  Denzel Washington Reveals the Aftermath of Wil...
#
#                      publishedAt                 channelId       channelTitle  \
# 0      2020-08-11 19:20:14+00:00  UCvtRTOMP2TqYqu51xNrqAzg           Brawadis
# 1      2020-08-11 20:24:34+00:00  UCtinbF-Q-fVthA0qrFQTgXQ       CaseyNeistat
# 2      2020-08-11 17:00:31+00:00  UCYJPby9DRCteedh5tfxVbrw          Smosh Pit
# 3      2020-08-11 22:00:05+00:00  UCMw7m-ScQ6jV1FQzQnn1y8Q      Tyler Cameron
# 4      2020-08-11 23:00:06+00:00  UCuxlXCfVyV-i5YLL30jkomw  Cole The Cornstar
# ...                          ...                       ...                ...
# 199185 2022-04-03 14:58:54+00:00  UCjQbTcszB-gRhDByY9WhySw         T.D. Jakes
# 199186 2022-04-03 14:58:54+00:00  UCjQbTcszB-gRhDByY9WhySw         T.D. Jakes
# 199187 2022-04-03 14:58:54+00:00  UCjQbTcszB-gRhDByY9WhySw         T.D. Jakes
# 199188 2022-04-03 14:58:54+00:00  UCjQbTcszB-gRhDByY9WhySw         T.D. Jakes
# 199189 2022-04-03 14:58:54+00:00  UCjQbTcszB-gRhDByY9WhySw         T.D. Jakes
#
#         categoryId             trending_date  view_count   likes  dislikes  \
# 0               22 2020-08-12 00:00:00+00:00     1514614  156908      5855
# 1               22 2020-08-12 00:00:00+00:00      940036   87111      1860
# 2               22 2020-08-12 00:00:00+00:00      591837   44168       409
# 3               22 2020-08-12 00:00:00+00:00      105955    4511        69
# 4               22 2020-08-12 00:00:00+00:00      277338   37533       197
# ...            ...                       ...         ...     ...       ...
# 199185          29 2022-04-26 00:00:00+00:00     5993854   70282         0
# 199186          29 2022-04-27 00:00:00+00:00     6003393   70402         0
# 199187          29 2022-04-29 00:00:00+00:00     6017799   70619         0
# 199188          29 2022-04-30 00:00:00+00:00     6023847   70704         0
# 199189          29 2022-05-04 00:00:00+00:00     6045361   71043         0
#
#         comment_count  comments_disabled  ratings_disabled  p_year p_month  \
# 0               35313              False             False    2020  August
# 1                7052              False             False    2020  August
# 2                2652              False             False    2020  August
# 3                 673              False             False    2020  August
# 4                3666              False             False    2020  August
# ...               ...                ...               ...     ...     ...
# 199185          19460              False             False    2022   April
# 199186          19470              False             False    2022   April
# 199187          19474              False             False    2022   April
# 199188          19467              False             False    2022   April
# 199189          19442              False             False    2022   April
#
#         t_year t_month                  Genre
# 0         2020  August         People & Blogs
# 1         2020  August         People & Blogs
# 2         2020  August         People & Blogs
# 3         2020  August         People & Blogs
# 4         2020  August         People & Blogs
# ...        ...     ...                    ...
# 199185    2022   April  Nonprofits & Activism
# 199186    2022   April  Nonprofits & Activism
# 199187    2022   April  Nonprofits & Activism
# 199188    2022   April  Nonprofits & Activism
# 199189    2022     May  Nonprofits & Activism
#
# [199190 rows x 18 columns]

# %%
odf = df.groupby(by='video_id').max()

# %%
sns.barplot(y=odf['Genre'],x=odf['view_count'],estimator=sum)
# Out:
# <Axes: xlabel='view_count', ylabel='Genre'>

# %%
sns.barplot(y=odf['Genre'],x=odf['likes'])
# Out:
# <Axes: xlabel='likes', ylabel='Genre'>

# %%
c=widgets.Dropdown(
    options=['likes','view_count','dislikes'],
    value='likes',
    description='Graph:',
    disabled=False,
)
def graph(a):
  sns.barplot(y='Genre',x=a, data=odf, estimator=sum)
  plt.show()

# %%
widgets.interact(graph, a = c)
# Out:
# interactive(children=(Dropdown(description='Graph:', options=('likes', 'view_count', 'dislikes'), value='likes…
# <function __main__.graph(a)>

# %%
data.groupby(by='p_year').count()

# %%
sns.barplot(x=odf['p_year'],y=odf['view_count'],estimator=len)
# Out:
# <Axes: xlabel='p_year', ylabel='view_count'>

# %%
non = odf[odf['Genre']=='Sports']

# %%
non.groupby(by='channelTitle').sum().sort_values(by='view_count',ascending=False)
# Out:
# <ipython-input-127-c6be4bd80a31>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   non.groupby(by='channelTitle').sum().sort_values(by='view_count',ascending=False)
#                        categoryId  view_count     likes  dislikes  \
# channelTitle
# NFL                          5593   874000181  13768491    196900
# NBA                          5576   728587293   7831993    147444
# Dude Perfect                 1122   575470608  22735313    256533
# FORMULA 1                    1088   298614499   6494504     82871
# That's Amazing Shorts         119   198110470  13543924    278058
# ...                           ...         ...       ...       ...
# Yung Mustard                   17       95221      2627        89
# Fox League                     17       90446       973         0
# Ariel Helwani                  17       78031      4100       161
# NFL Highlights HD              17       69829       475         0
# BW TV                          17       46133       302         0
#
#                        comment_count  comments_disabled  ratings_disabled  \
# channelTitle
# NFL                          1811375                  0                 3
# NBA                          1294850                  0                 0
# Dude Perfect                 1141029                  0                 0
# FORMULA 1                     419768                  0                 3
# That's Amazing Shorts          53704                  0                 1
# ...                              ...                ...               ...
# Yung Mustard                     904                  0                 0
# Fox League                       100                  0                 0
# Ariel Helwani                   1074                  0                 0
# NFL Highlights HD                 68                  0                 0
# BW TV                             25                  0                 0
#
#                        p_year  t_year
# channelTitle
# NFL                    665000  665009
# NBA                    663012  663020
# Dude Perfect           133403  133405
# FORMULA 1              129384  129384
# That's Amazing Shorts   14147   14147
# ...                       ...     ...
# Yung Mustard             2020    2020
# Fox League               2022    2022
# Ariel Helwani            2021    2021
# NFL Highlights HD        2022    2022
# BW TV                    2022    2022
#
# [573 rows x 9 columns]

# %%
c=widgets.Dropdown(
    options=odf['Genre'].unique(),
    value='Sports',
    description='Graph:',
    disabled=False,
)
def graph(a):
  non = odf[odf['Genre']==a]
  dd = non.groupby(by='channelTitle').sum().sort_values(by='view_count',ascending=False).head(10)
  sns.barplot(y=dd.index,x=dd['view_count'])
  plt.title(a)
  plt.show()
  #plt.xticks(rotation = 45)

# %%
widgets.interact(graph, a = c)
# Out:
# interactive(children=(Dropdown(description='Graph:', index=2, options=('Music', 'Entertainment', 'Sports', 'Ed…
# <function __main__.graph(a)>

# %%
odf['channelTitle'].unique()
# Out:
# array(['MigosVEVO', 'jf.okay', 'Television Academy', ..., 'thought',
#        'Lakeland PBS', 'Magnolia Network'], dtype=object)

# %%
odf.reset_index(inplace = True)

# %%
x = odf[['likes','dislikes','comment_count','Genre']]

# %%
x
# Out:
#         likes  dislikes  comment_count           Genre
# 0      262692      4107          16445           Music
# 1       17290         0           1439   Entertainment
# 2        8029       369            723   Entertainment
# 3       14603         0           2078          Sports
# 4       29991       320            998       Education
# ...       ...       ...            ...             ...
# 36274   47431         0           3586  People & Blogs
# 36275  728439      7579          57012           Music
# 36276   20024       989           2872          Sports
# 36277  584431      3403          77267           Music
# 36278   70776         0           2061          Gaming
#
# [36279 rows x 4 columns]

# %%
y = odf[['view_count']]

# %%
y
# Out:
#        view_count
# 0         6823249
# 1          538485
# 2          682609
# 3         1280997
# 4          623949
# ...           ...
# 36274     2603821
# 36275    13974461
# 36276     2598512
# 36277     9389223
# 36278     3079200
#
# [36279 rows x 1 columns]

# %%
le = LabelEncoder()

# %%
x['Genre'] = le.fit_transform(x['Genre'])
# Out:
# <ipython-input-167-4c8aa30c36b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Genre'] = le.fit_transform(x['Genre'])

# %%
x
# Out:
#         likes  dislikes  comment_count  Genre
# 0      262692      4107          16445      7
# 1       17290         0           1439      3
# 2        8029       369            723      3
# 3       14603         0           2078     13
# 4       29991       320            998      2
# ...       ...       ...            ...    ...
# 36274   47431         0           3586     10
# 36275  728439      7579          57012      7
# 36276   20024       989           2872     13
# 36277  584431      3403          77267      7
# 36278   70776         0           2061      5
#
# [36279 rows x 4 columns]

# %%
#x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
x_train,x_test = x[:20000],x[20000:]
y_train,y_test = y[:20000],y[20000:]

# %%
x_train
# Out:
#         likes  dislikes  comment_count  Genre
# 0      262692      4107          16445      7
# 1       17290         0           1439      3
# 2        8029       369            723      3
# 3       14603         0           2078     13
# 4       29991       320            998      2
# ...       ...       ...            ...    ...
# 19995  245947         0          11373      5
# 19996    7174       293           6473      8
# 19997   35010         0           3307      2
# 19998   23263         0           1518      7
# 19999  206161         0           9818      7
#
# [20000 rows x 4 columns]

# %%
y_train
# Out:
#        view_count
# 0         6823249
# 1          538485
# 2          682609
# 3         1280997
# 4          623949
# ...           ...
# 19995     3541107
# 19996      379442
# 19997     1176345
# 19998      509873
# 19999     1383688
#
# [20000 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.7226031180878119

# %%
lr.predict(x_test.head(10))
# Out:
# array([[ 678471.50202642],
#        [1426758.18684917],
#        [1870040.48613071],
#        [ 983904.27274158],
#        [ 957880.9287186 ],
#        [1379665.88361323],
#        [2167205.80741872],
#        [1130246.71991688],
#        [1680582.76635784],
#        [1012838.93905977]])

# %%
np.array(y_test)
# Out:
# array([[ 337965],
#        [1231498],
#        [1396830],
#        ...,
#        [2598512],
#        [9389223],
#        [3079200]])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# <ipython-input-203-895403b03771>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# RandomForestRegressor()

# %%
rf.score(x_test,y_test)
# Out:
# 0.7320006110351855

# %%
rf.predict(x_test.head(10))
# Out:
# array([ 388251.18,  937475.89, 1271650.89,  617065.04,  792745.29,
#        1375549.65, 2301061.77, 1481963.35, 1130468.9 ,  519388.45])

# %%
np.array(y_test)
# Out:
# array([[ 337965],
#        [1231498],
#        [1396830],
#        ...,
#        [2598512],
#        [9389223],
#        [3079200]])
